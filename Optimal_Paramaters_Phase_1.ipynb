# %% [markdown]
# <a href="https://colab.research.google.com/github/kerry-tarrant/Pump-Parameters-For-Cell-Volume-Model/blob/main/Optimal_Paramaters_Phase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# raw=true downloads the file and not the webpage.
# !wget https://github.com/kerry-tarrant/Pump-Parameters-For-Cell-Volume-Model/blob/main/volume-time-data/volumes_and_times.mat?raw=true
# Out:
# --2022-03-25 02:00:32--  https://github.com/kerry-tarrant/Pump-Parameters-For-Cell-Volume-Model/blob/main/volume-time-data/volumes_and_times.mat?raw=true
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/kerry-tarrant/Pump-Parameters-For-Cell-Volume-Model/raw/main/volume-time-data/volumes_and_times.mat [following]
# --2022-03-25 02:00:33--  https://github.com/kerry-tarrant/Pump-Parameters-For-Cell-Volume-Model/raw/main/volume-time-data/volumes_and_times.mat
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kerry-tarrant/Pump-Parameters-For-Cell-Volume-Model/main/volume-time-data/volumes_and_times.mat [following]
# ...

# %%
# rename the file
# !mv volumes_and_times.mat\?raw\=true data.mat

# %%
# update scipy
# !pip install -U -q scipy
# Load the data
from scipy import io
v = io.loadmat('data.mat')
print(v.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'time', 'volumes'])

# %%
# data to arrays
all_time = v['time']
all_volumes = v['volumes']
print('Time:',all_time[0],
      '\n\nVolume:',all_volumes[0]) # arrays should are almost ready
# Out:
# Time: [0.00000000e+00 4.44665394e-02 1.12809753e-01 2.91810177e-01
#  1.18681230e+00 2.08181442e+00 2.62443999e+00 3.16706555e+00
#  3.90760806e+00 4.64815057e+00 5.31387767e+00 5.97960477e+00
#  6.68028859e+00 7.38097240e+00 8.08156895e+00 8.78216550e+00
#  9.49593527e+00 1.02097051e+01 1.09335267e+01 1.16573483e+01
#  1.23937449e+01 1.31301414e+01 1.38798075e+01 1.46294735e+01
#  1.53938419e+01 1.61582104e+01 1.69385777e+01 1.77189449e+01
#  1.85167939e+01 1.93146429e+01 2.01315365e+01 2.09484301e+01
#  2.17860713e+01 2.26237124e+01 2.34839323e+01 2.43441522e+01
#  2.52289407e+01 2.61137293e+01 2.70252349e+01 2.79367405e+01
#  2.88773160e+01 2.98178914e+01 3.07900559e+01 3.17622203e+01
#  3.27687467e+01 3.37752732e+01 3.48191771e+01 3.58630810e+01
#  3.69475974e+01 3.80321137e+01 3.91608043e+01 4.02894949e+01
#  4.14662076e+01 4.26429203e+01 4.38718024e+01 4.51006845e+01
#  4.63862515e+01 4.76718185e+01 4.90189232e+01 5.03660280e+01
# ...
